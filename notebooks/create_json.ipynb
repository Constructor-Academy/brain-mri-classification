# %% [markdown]
# ## Create a .json file from labelled images

# %%
from pathlib import Path
import os
import json

# %% [markdown]
# Get all file names as path object

# %%
cwd = os.getcwd()
wd = Path(cwd).parents[0]

# %%
file_list = [p for p in wd.joinpath('data/images').iterdir() if p.is_file()]

# %%
#file_list

# %% [markdown]
# Convert path object to string, remove `data` and `images` part of string

# %%
string_file_list = [p.as_posix().split('/')[-1] for p in file_list]

# %%
string_file_list = [p.split('.')[0] for p in string_file_list] # remove '.jpg'

# %%
string_file_list
# Out:
# ['AX_PWI_Glioma_GBM_TCGA060173_1',
#  'AX_DWI_Glioma_GBM_TCGA020087_2',
#  'AX_ADC_Glioma_GBM_TCGA766662_1',
#  'COR_T1KM_Glioma_GBM_TCGA766663_2',
#  'SAG_T1KM_Glioma_GBM_TCGA020116_2',
#  'SAG_T1KM_Glioma_GBM_TCGA020068_1',
#  'SAG_Misc_Glioma_GBM_TCGA766657_2',
#  'COR_T1KM_Glioma_GBM_TCGA060171_2',
#  'AX_DWI_Glioma_GBM_TCGA141829_1',
#  'COR_Misc_Glioma_GBM_TCGA766661_2',
#  'COR_T1KM_Glioma_GBM_TCGA020085_2',
#  'AX_T2_Glioma_GBM_TCGA120829_1',
#  'AX_T2_Glioma_GBM_TCGA020006_1',
#  'AX_DWI_Glioma_GBM_TCGA060168_1',
#  'COR_T1KM_Glioma_GBM_TCGA020106_1',
#  'SAG_T1KM_Glioma_GBM_TCGA020034_1',
#  'COR_T1KM_Glioma_GBM_TCGA020087_1',
#  'AX_DWI_Glioma_GBM_TCGA766663_1',
#  'COR_Misc_Glioma_GBM_TCGA766661_3',
#  'COR_T1KM_Glioma_GBM_TCGA141829_2',
#  'AX_PWI_Glioma_GBM_TCGA060213_1',
#  'SAG_Misc_Glioma_GBM_TCGA766657_3',
#  'COR_T1KM_Glioma_GBM_TCGA02086_1',
#  'AX_DWI_Glioma_GBM_TCGA020085_1',
#  'AX_PWI_Glioma_GBM_TCGA060157_1',
#  'COR_T1KM_Glioma_GBM_TCGA020047_1',
#  'SAG_T1KM_Glioma_GBM_TCGA020009_1',
#  'AX_T2_Glioma_GBM_TCGA766661_4',
#  'AX_ADC_Glioma_GBM_TCGA766662_2',
#  'AX_DWI_Glioma_GBM_TCGA020087_1',
#  'SAG_T1KM_Glioma_GBM_TCGA020116_1',
#  'COR_T1KM_Glioma_GBM_TCGA766663_1',
#  'SAG_T1KM_Glioma_GBM_TCGA020068_2',
#  'SAG_Misc_Glioma_GBM_TCGA766657_1',
#  'AX_DWI_Glioma_GBM_TCGA02-0046_1',
#  'SAG_T1_Glioma_GBM_TCGA060122_1',
#  'COR_Misc_Glioma_GBM_TCGA766661_1',
#  'COR_T1KM_Glioma_GBM_TCGA020085_1',
#  'COR_T1KM_Glioma_GBM_TCGA020106_2',
#  'AX_DWI_Glioma_GBM_TCGA766663_3',
#  'SAG_T1KM_Glioma_GBM_TCGA020034_2',
#  'AX_T1_Glioma_GBM_TCGA020069_1',
#  'AX_DWI_Glioma_GBM_TCGA766663_2',
#  'AX_T1_Glioma_GBM_TCGA060125_1',
#  'SAG_T1_Glioma_GBM_TCGA060143_1',
#  'AX_PWI_Glioma_GBM_TCGA060213_2',
#  'COR_T1KM_Glioma_GBM_TCGA141829_1',
#  'SAG_T1KM_Glioma_GBM_TCGA020068_3',
#  'AX_T2_Glioma_GBM_TCGA065412_1',
#  'AX_DWI_Glioma_GBM_TCGA020106_1',
#  'COR_T1KM_Glioma_GBM_TCGA020047_2',
#  'AX_ADC_Glioma_GBM_TCGA766662_3',
#  'AX_T1_Glioma_GBM_TCGA120769_1',
#  'AX_T2_Glioma_GBM_TCGA766661_3',
#  'AX_T1_Glioma_GBM_TCGA061084_1',
#  'SAG_T1_Glioma_GBM_TCGA764934_1',
#  'AX_T2_Glioma_GBM_TCGA766663_1',
#  'SAG_T1KM_Glioma_GBM_TCGA020075_2',
#  'SAG_Misc_Glioma_GBM_TCGA766657_4',
#  'AX_T1KM_Glioma_GBM_TCGA060121_1',
#  'SAG_T1_Glioma_GBM_TCGA766657_3',
#  '',
#  'SAG_T1_Glioma_GBM_TCGA061802_2',
#  'AX_T2_Glioma_GBM_TCGA060213_2',
#  'COR_T1KM_Glioma_GBM_TCGA120829_2',
#  'AX_T1KM_Glioma_GBM_TCGA120769_1',
#  'AX_T2_Glioma_GBM_TCGA060157_2',
#  'AX_T1KM_Glioma_GBM_TCGA020011_4',
#  'SAG_T1KM_Glioma_GBM_TCGA120616_1',
#  'SAG_T1_Glioma_GBM_TCGA766657_2',
#  'AX_T2_Glioma_GBM_TCGA020087_2',
#  'AX_DWI_Glioma_GBM_TCGA020006_1',
#  'SAG_T1_Glioma_GBM_TCGA060878_1',
#  'SAG_T1KM_Glioma_GBM_TCGA020075_3',
#  'AX_T2_Glioma_GBM_TCGA060168_1',
#  'AX_Misc_Glioma_GBM_TCGA060121_2',
#  'COR_T1KM_Glioma_GBM_TCGA065412_1',
#  'AX_T2_Glioma_GBM_TCGA141829_1',
#  'AX_T2_Glioma_GBM_TCGA766661_2',
#  'AX_T1KM_Glioma_GBM_TCGA120772_1',
#  'AX_T1_Glioma_GBM_TCGA061084_2',
#  'SAG_T1KM_Glioma_GBM_TCGA020075_1',
#  'AX_T2_Glioma_GBM_TCGA020106_1',
#  'SAG_T1KM_Glioma_GBM_TCGA020048_1',
#  'AX_T1_Glioma_GBM_TCGA020033_1',
#  'SAG_T1_Glioma_GBM_TCGA060119_1',
#  'COR_T1KM_Glioma_GBM_TCGA020006_1',
#  'SAG_T1_Glioma_GBM_TCGA061802_1',
#  'COR_T1KM_Glioma_GBM_TCGA120829_1',
#  'AX_T2_Glioma_GBM_TCGA060213_1',
#  'AX_DWI_Glioma_GBM_TCGA065412_1',
#  'AX_T2_Glioma_GBM_TCGA060157_1',
#  'AX_T2_Glioma_GBM_TGCA020037_1',
#  'AX_T2_Glioma_GBM_TCGA060173_1',
#  'SAG_T1_Glioma_GBM_TCGA766657_1',
#  'AX_T2_Glioma_GBM_TCGA020087_1',
#  'COR_T1KM_Glioma_GBM_TCGA020102_1',
#  'AX_Misc_Glioma_GBM_TCGA060121_1',
#  'AX_T2_Glioma_GBM_TCGA766661_1',
#  'AX_T2_Glioma_GBM_TCGA141829_2',
#  'AX_T2_Glioma_GBM_TCGA060128_1',
#  'COR_T1KM_Glioma_GBM_TCGA141037_1',
#  'AX_T2_Glioma_GBM_TCGA020064_1',
#  'AX_T1KM_Glioma_GBM_TCGA766657_1',
#  'AX_DWI_Glioma_GBM_TCGA020003_1',
#  'AX_Misc_Glioma_GBM_TCGA764934_1',
#  'SAG_T1KM_Glioma_GBM_TCGA020011_2',
#  'SAG_T1KM_Glioma_GBM_TCGA020037_1',
#  'AX_T1KM_Glioma_GBM_TCGA020009_1',
#  'COR_T1KM_Glioma_GBM_TCGA020027_2',
#  'AX_ADC_Glioma_GBM_TCGA766663_2',
#  'COR_T1KM_Glioma_GBM_TCGA766662_1',
#  'COR_T1KM_Glioma_GBM_TCGA020060_1',
#  'COR_T1KM_Glioma_GBM_TCGA060644_1',
#  'AX_ADC_Glioma_GBM_TCGA766663_3',
#  'COR_T1KM_Glioma_GBM_TCGA020046_2',
#  'AX_T1_Glioma_GBM_TCGA060119_1',
#  'AX_T1_Glioma_GBM_TCGA061802_1',
#  'AX_ADC_Glioma_GBM_TCGA766661_1',
#  'AX_T2_Glioma_GBM_TCGA060189_1',
#  'SAG_T1KM_Glioma_GBM_TCGA020011_3',
#  'SAG_T1_Glioma_GBM_TCGA061084_2',
#  'AX_T1KM_Glioma_GBM_TCGA061802_1',
#  'COR_T1KM_Glioma_GBM_TCGA020086_2',
#  'AX_T1_Glioma_GBM_TCGA020068_1',
#  'AX_T1KM_Glioma_GBM_TCGA060119_1',
#  'SAG_T1_Glioma_GBM_TCGA060121_2',
#  'AX_PD_Glioma_GBM_TCGA766657_1',
#  'AX_T2_Glioma_GBM_TCGA060128_2',
#  'AX_T1_Glioma_GBM_TCGA060878_1',
#  'COR_T1KM_Glioma_GBM_TCGA141037_2',
#  'AX_T2_Glioma_GBM_TCGA020064_2',
#  'AX_DWI_Glioma_GBM_TCGA020003_2',
#  'AX_DWI_Glioma_GBM_TCGA060644_1',
#  'AX_T2_Glioma_GBM_TCGA766664_1',
#  'SAG_T1KM_Glioma_GBM_TCGA020037_2',
#  'SAG_T1KM_Glioma_GBM_TCGA020011_1',
#  'AX_T2_Glioma_GBM_TCGA020003_5',
#  'SAG_T1KM_Glioma_GBM_TCGA020069_1',
#  'COR_T1KM_Glioma_GBM_TCGA020027_1',
#  'AX_ADC_Glioma_GBM_TCGA766661_3',
#  'AX_T1KM_Glioma_GBM_TCGA060878_1',
#  'AX_ADC_Glioma_GBM_TCGA766663_1',
#  'COR_T1KM_Glioma_GBM_TCGA766662_2',
#  'COR_T1KM_Glioma_GBM_TCGA020003_1',
#  'COR_T1KM_Glioma_GBM_TCGA020046_1',
#  'COR_T1KM_Glioma_GBM_TCGA020060_2',
#  'AX_ADC_Glioma_GBM_TCGA766661_2',
#  'AX_T2_Glioma_GBM_TCGA020003_4',
#  'SAG_T1_Glioma_GBM_TCGA061084_1',
#  'SAG_T1KM_Glioma_GBM_TCGA020070_1',
#  'AX_DWI_Glioma_GBM_TCGA766662_1',
#  'SAG_T1_Glioma_GBM_TCGA060121_1',
#  'AX_T2_Glioma_GBM_TCGA060128_3',
#  'AX_PD_Glioma_GBM_TCGA766657_2',
#  'COR_T1KM_Glioma_GBM_TCGA766664_1',
#  'AX_DWI_Glioma_GBM_TCGA060189_1',
#  'AX_PWI_Glioma_GBM_TCGA060189_2',
#  'AX_T1KM_Glioma_GBM_TCGA060143_1',
#  'AX_T1KM_Glioma_GBM_TCGA120616_1',
#  'AX_T2_Glioma_GBM_TCGA141037_2',
#  'COR_T1KM_Glioma_GBM_TCGA020064_2',
#  'SAG_T1_Glioma_GBM_TCGA060125_1',
#  'COR_T1KM_Glioma_GBM_TCGA020059_2',
#  'AX_PWI_Glioma_GBM_TCGA060128_3',
#  'AX_T1_Glioma_GBM_TCGA060143_1',
#  'COR_T1KM_Glioma_GBM_TCGA060189_2',
#  'AX_DWI_Glioma_GBM_TCGA020064_1',
#  'AX_PWI_Glioma_GBM_TCGA060128_2',
#  'COR_T1KM_Glioma_GBM_TCGA020059_3',
#  'AX_T2_Glioma_GBM_TCGA020003_1',
#  'COR_T1KM_Glioma_GBM_TCGA020064_3',
#  'AX_PD_Glioma_GBM_TCGA120616_1',
#  'AX_T2_Glioma_GBM_TCGA080244_1',
#  'COR_T2_Glioma_GBM_TCGA080349_1',
#  'AX_DWI_Glioma_GBM_TCGA020059_1',
#  'AX_T1KM_Glioma_GBM_TCGA060122_1',
#  'AX_T2_Glioma_GBM_TCGA060128_4',
#  'AX_DWI_Glioma_GBM_TCGA060189_2',
#  'COR_T1KM_Glioma_GBM_TCGA766664_2',
#  'AX_PWI_Glioma_GBM_TCGA060189_1',
#  'AX_DWI_Glioma_GBM_TCGA020059_3',
#  'AX_T2_Glioma_GBM_TCGA141037_1',
#  'COR_T1KM_Glioma_GBM_TCGA020064_1',
#  'COR_T2_Glioma_GBM_TCGA080349_3',
#  'AX_PD_Glioma_GBM_TCGA120616_3',
#  'AX_T2_Glioma_GBM_TCGA020003_3',
#  'SAG_T1_Glioma_GBM_TCGA060125_2',
#  'COR_T1KM_Glioma_GBM_TCGA020059_1',
#  'AX_T2_Glioma_GBM_TCGA766662_1',
#  'COR_T1KM_Glioma_GBM_TCGA060189_1',
#  'AX_T1KM_Glioma_GBM_TCGA020075_1',
#  'SAG_T1KM_Glioma_GBM_TCGA020033_1',
#  'AX_DWI_Glioma_GBM_TCGA020064_2',
#  'AX_PWI_Glioma_GBM_TCGA060128_1',
#  'SAG_T1KM_Glioma_GBM_TCGA120772_1',
#  'AX_T2_Glioma_GBM_TCGA020003_2',
#  'AX_T2_Glioma_GBM_TCGA060644_1',
#  'AX_T2_Glioma_GBM_TCGA020060_1',
#  'AX_PD_Glioma_GBM_TCGA120616_2',
#  'COR_T2_Glioma_GBM_TCGA080349_2',
#  'AX_T2_Glioma_GBM_TCGA080244_2',
#  'AX_DWI_Glioma_GBM_TCGA020059_2',
#  'COR_T1KM_Glioma_GBM_TCGA141037_5',
#  'AX_T1_Glioma_GBM_TCGA020075_1',
#  'AX_PWI_Glioma_GBM_TCGA060119_1',
#  'SAG_T1_Glioma_GBM_TCGA766661_4',
#  'COR_Misc_Glioma_GBM_TCGA766657_3',
#  'AX_T1KM_Glioma_GBM_TCGA766662_1',
#  'AX_T1_Glioma_GBM_TCGA141037_1',
#  'COR_T1KM_Glioma_GBM_TCGA020009_1',
#  'SAG_T1KM_Glioma_GBM_TCGA020047_1',
#  'COR_T1KM_Glioma_GBM_TCGA764934_3',
#  'COR_T1KM_Glioma_GBM_TCGA020034_1',
#  'SAG_T1KM_Glioma_GBM_TCGA020087_1',
#  'AX_T1KM_Glioma_GBM_TCGA141037_1',
#  'AX_T1_Glioma_GBM_TCGA766662_1',
#  'SAG_Misc_Glioma_GBM_TCGA766661_3',
#  'SAG_T1KM_Glioma_GBM_TCGA020085_2',
#  'AX_DWI_Glioma_GBM_TCGA060878_1',
#  'SAG_Misc_Glioma_GBM_TCGA766661_2',
#  'COR_T1KM_Glioma_GBM_TCGA060119_1',
#  'AX_T1_Glioma_GBM_TCGA060644_1',
#  'SAG_T1KM_Glioma_GBM_TCGA020106_1',
#  'COR_T1KM_Glioma_GBM_TCGA061802_1',
#  'SAG_T1KM_Glioma_GBM_TCGA766663_2',
#  'COR_T1KM_Glioma_GBM_TCGA764934_2',
#  'COR_T1KM_Glioma_GBM_TCGA020116_2',
#  'SAG_T1KM_Glioma_GBM_TCGA02086_1',
#  'AX_T2_Glioma_GBM_TCGA020075_1',
#  'COR_Misc_Glioma_GBM_TCGA766657_2',
#  'AX_Misc_Glioma_GBM_TCGA764925_1',
#  'AX_T1KM_Glioma_GBM_TCGA060644_1',
#  'AX_T1KM_Glioma_GBM_TCGA020003_2',
#  'COR_T1KM_Glioma_GBM_TCGA020068_1',
#  'AX_T1_Glioma_GBM_TCGA764925_1',
#  'COR_T1KM_Glioma_GBM_TCGA020068_3',
#  'COR_T1KM_Glioma_GBM_TCGA060878_1',
#  'AX_T1_Glioma_GBM_TCGA141037_2',
#  'AX_DWI_Glioma_GBM_TCGA060119_1',
#  'SAG_T1KM_Glioma_GBM_TCGA141829_1',
#  'AX_T2_Glioma_GBM_TCGA020075_3',
#  'SAG_T1KM_Glioma_GBM_TCGA020047_2',
#  'SAG_T1_Glioma_GBM_TCGA065412_1',
#  'AX_T1_Glioma_GBM_TCGA020027_1',
#  'COR_T1KM_Glioma_GBM_TCGA020034_2',
#  'AX_DWI_Glioma_GBM_TCGA020068_1',
#  'AX_T1KM_Glioma_GBM_TCGA141037_2',
#  'COR_T1KM_Glioma_GBM_TCGA060119_3',
#  'AX_T2_Glioma_GBM_TCGA120616_1',
#  'AX_T2_Glioma_GBM_TCGA060143_1',
#  'SAG_T1KM_Glioma_GBM_TCGA020085_1',
#  'SAG_Misc_Glioma_GBM_TCGA766661_1',
#  'COR_T1KM_Glioma_GBM_TCGA060119_2',
#  'AX_T1_Glioma_GBM_TCGA020003_1',
#  'AX_T2_Glioma_GBM_TCGA060122_1',
#  'SAG_T1KM_Glioma_GBM_TCGA020106_2',
#  'COR_T1KM_Glioma_GBM_TCGA020116_1',
#  'SAG_T1KM_Glioma_GBM_TCGA766663_1',
#  'COR_T1KM_Glioma_GBM_TCGA764934_1',
#  'AX_T2_Glioma_GBM_TCGA020075_2',
#  'AX_Misc_Glioma_GBM_TCGA764925_2',
#  'COR_Misc_Glioma_GBM_TCGA766657_1',
#  'AX_T1KM_Glioma_GBM_TCGA020003_1',
#  'SAG_T1KM_Glioma_GBM_TCGA020045_1',
#  'COR_T1KM_Glioma_GBM_TCGA020068_2',
#  'AX_DWI_Glioma_GBM_TCGA060122_2',
#  'COR_T1KM_Glioma_GBM_TCGA020075_3',
#  'SAG_T1_Glioma_GBM_TCGA141829_1',
#  'SAG_T1_Glioma_GBM_TCGA766661_2',
#  'AX_T1KM_Glioma_GBM_TCGA020003_5',
#  'AX_T2_Glioma_GBM_TCGA020068_3',
#  'SAG_T1_Glioma_GBM_TCGA060168_1',
#  'COR_T1KM_Glioma_GBM_TCGA060143_1',
#  'AX_Misc_Glioma_GBM_TCGA060189_1',
#  'AX_T1KM_Glioma_GBM_TCGA766664_1',
#  'COR_T2_Glioma_GBM_TCGA141829_2',
#  'SAG_T1_Glioma_GBM_TCGA060157_2',
#  'COR_T1KM_Glioma_GBM_TCGA060122_1',
#  'SAG_T1_Glioma_GBM_TCGA060171_1',
#  'COR_T1KM_Glioma_GBM_TCGA020048_2',
#  'SAG_T1_Glioma_GBM_TCGA766663_1',
#  'AX_T2_Glioma_GBM_TCGA020068_2',
#  'AX_DWI_Glioma_GBM_TCGA060143_2',
#  'SAG_T1_Glioma_GBM_TCGA766661_3',
#  'AX_T1KM_Glioma_GBM_TCGA020003_4',
#  'COR_T1KM_Glioma_GBM_TCGA020075_2',
#  'COR_Misc_Glioma_GBM_TCGA766657_4',
#  'AX_Misc_Glioma_GBM_TCGA766192_1',
#  'AX_T2_Glioma_GBM_TCGA764934_1',
#  'AX_DWI_Glioma_GBM_TCGA060122_1',
#  'AX_Misc_Glioma_GBM_TCGA766192_3',
#  'AX_T1KM_Glioma_GBM_TCGA020003_6',
#  'AX_T2_Glioma_GBM_TCGA020009_1',
#  'SAG_T1_Glioma_GBM_TCGA766661_1',
#  'SAG_T1KM_Glioma_GBM_TCGA020102_1',
#  'AX_T1_Glioma_GBM_TCGA020064_1',
#  'SAG_T1_Glioma_GBM_TCGA060173_1',
#  'COR_T2_Glioma_GBM_TCGA141829_1',
#  'SAG_T1KM_Glioma_GBM_TCGA020006_1',
#  'AX_T2_Glioma_GBM_TCGA061802_1',
#  'SAG_T1_Glioma_GBM_TCGA060171_2',
#  'AX_T1_Glioma_GBM_TCGA060189_1',
#  'COR_T1KM_Glioma_GBM_TCGA020048_1',
#  'AX_T2_Glioma_GBM_TCGA020068_1',
#  'SAG_T1_Glioma_GBM_TCGA766663_2',
#  'AX_T2_Glioma_GBM_TCGA020075_4',
#  'AX_DWI_Glioma_GBM_TCGA060143_1',
#  'AX_DWI_Glioma_GBM_TCGA120616_1',
#  'AX_Misc_Glioma_GBM_TCGA766664_1',
#  'AX_T1KM_Glioma_GBM_TCGA060189_1',
#  'COR_T1KM_Glioma_GBM_TCGA020075_1',
#  'AX_T2_Glioma_GBM_TCGA764934_2',
#  'AX_Misc_Glioma_GBM_TCGA766192_2',
#  'COR_Misc_Glioma_GBM_TCGA020069_1',
#  'AX_DWI_Glioma_GBM_TCGA020069_1',
#  'AX_T1KM_Glioma_GBM_TCGA020106_1',
#  'AX_PD_Glioma_GBM_TCGA060173_1',
#  'COR_T1KM_Glioma_GBM_TCGA020011_3',
#  'AX_T2_Glioma_GBM_TCGA060121_2',
#  'AX_T1KM_Glioma_GBM_TCGA060157_1',
#  'AX_T1KM_Glioma_GBM_TCGA060171_2',
#  'AX_Misc_Glioma_GBM_TCGA141829_1',
#  'AX_T2_Glioma_GBM_TCGA061084_2',
#  'AX_T1KM_Glioma_GBM_TCGA060213_1',
#  'SAG_T1KM_Glioma_GBM_TCGA020086_2',
#  'AX_T1_Glioma_GBM_TCGA060213_1',
#  'SAG_T1KM_Glioma_GBM_TCGA020060_1',
#  'SAG_T1KM_Glioma_GBM_TCGA020046_2',
#  'AX_T1_Glioma_GBM_TCGA060157_1',
#  'SAG_T1_Glioma_GBM_TCGA060189_1',
#  'AX_T2_Glioma_GBM_TCGA120772_1',
#  'AX_T2_Glioma_GBM_TCGA020033_1',
#  'AX_T1_Glioma_GBM_TCGA020106_1',
#  'COR_Misc_Glioma_GBM_TCGA020054_1',
#  'AX_DWI_Glioma_GBM_TCGA020054_1',
#  'AX_DWI_Glioma_GBM_TCGA020011_1',
#  'AX_T1_Glioma_GBM_TCGA060173_1',
#  'AX_T1_Glioma_GBM_TCGA020087_1',
#  'SAG_T1KM_Glioma_GBM_TCGA766662_1',
#  'COR_Misc_Glioma_GBM_TCGA020070_1',
#  'AX_ADC_Glioma_GBM_TCGA764934_2',
#  'AX_DWI_Glioma_GBM_TCGA020070_1',
#  'AX_Misc_Glioma_GBM_TCGA060171_1',
#  'SAG_T1_Glioma_GBM_TCGA766664_2',
#  'AX_T1KM_Glioma_GBM_TCGA060171_3',
#  'AX_T1_Glioma_GBM_TCGA766661_1',
#  'SAG_T1KM_Glioma_GBM_TCGA141037_1',
#  'SAG_T1_Glioma_GBM_TCGA766192_1',
#  'COR_T1KM_Glioma_GBM_TCGA020054_2',
#  'COR_T1KM_Glioma_GBM_TCGA020011_2',
#  'AX_T1KM_Glioma_GBM_TCGA020087_1',
#  'COR_T1KM_Glioma_GBM_TCGA020037_1',
#  'AX_T1KM_Glioma_GBM_TCGA060173_1',
#  'COR_Misc_Glioma_GBM_TCGA020069_2',
#  'AX_T2_Glioma_GBM_TCGA060121_1',
#  'AX_T1KM_Glioma_GBM_TCGA060171_1',
#  'AX_T2_Glioma_GBM_TCGA120769_1',
#  'AX_T2_Glioma_GBM_TCGA061084_1',
#  'SAG_T1KM_Glioma_GBM_TCGA020046_1',
#  'SAG_T1KM_Glioma_GBM_TCGA020003_1',
#  'SAG_T1KM_Glioma_GBM_TCGA020060_2',
#  'AX_Misc_Glioma_GBM_TCGA060173_1',
#  'COR_Misc_Glioma_GBM_TCGA020054_2',
#  'AX_MRA_Glioma_GBM_TCGA060189_1',
#  'AX_T1KM_Glioma_GBM_TCGA060168_1',
#  'SAG_T1KM_Glioma_GBM_TCGA020027_1',
#  'COR_T1KM_Glioma_GBM_TCGA060125_1',
#  'AX_T1KM_Glioma_GBM_TCGA141829_1',
#  'AX_ADC_Glioma_GBM_TCGA764934_1',
#  'AX_PD_Glioma_GBM_TCGA060171_1',
#  'SAG_T1KM_Glioma_GBM_TCGA766664_4',
#  'SAG_T1_Glioma_GBM_TCGA766664_1',
#  'AX_T1_Glioma_GBM_TCGA766661_2',
#  'AX_T1_Glioma_GBM_TCGA141829_1',
#  'COR_T1KM_Glioma_GBM_TCGA020037_2',
#  'COR_T1KM_Glioma_GBM_TCGA020011_1',
#  'COR_T1KM_Glioma_GBM_TCGA020054_1',
#  'COR_T1KM_Glioma_GBM_TCGA061084_1',
#  'AX_MRA_Glioma_GBM_TCGA766192_4',
#  'SAG_T1KM_Glioma_GBM_TCGA020064_3',
#  'COR_T1KM_Glioma_GBM_TCGA120769_1',
#  'AX_ADC_Glioma_GBM_TCGA120616_1',
#  'COR_T1KM_Glioma_GBM_TCGA060121_1',
#  'AX_T1KM_Glioma_GBM_TCGA065412_1',
#  'AX_Misc_Glioma_GBM_TCGA191392_1',
#  'SAG_T1KM_Glioma_GBM_TCGA020059_2',
#  'AX_PWI_Glioma_GBM_TCGA061084_1',
#  'AX_T2_Glioma_GBM_TCGA060125_1',
#  'AX_DWI_Glioma_GBM_TCGA020033_1',
#  'SAG_T1KM_Glioma_GBM_TCGA766664_1',
#  'AX_T2_Glioma_GBM_TCGA020011_1',
#  'AX_T2_Glioma_GBM_TCGA020037_2',
#  'SAG_T1KM_Glioma_GBM_TCGA020064_2',
#  'AX_T1_Glioma_GBM_TCGA065412_1',
#  'COR_T1KM_Glioma_GBM_TCGA061084_2',
#  'AX_T1KM_Glioma_GBM_TCGA191392_1',
#  'AX_ADC_Glioma_GBM_TCGA120616_2',
#  'COR_T1KM_Glioma_GBM_TCGA060121_2',
#  'SAG_T1KM_Glioma_GBM_TCGA766664_3',
#  'AX_T2_Glioma_GBM_TCGA080349_1',
#  'SAG_T1_Glioma_GBM_TCGA060644_1',
#  'COR_T1KM_Glioma_GBM_TCGA020033_1',
#  'COR_T1KM_Glioma_GBM_TCGA120772_1',
#  'AX_T1_Glioma_GBM_TCGA120829_1',
#  'SAG_T1KM_Glioma_GBM_TCGA020059_1',
#  'SAG_T1KM_Glioma_GBM_TCGA766664_2',
#  'SAG_T1_Glioma_GBM_TCGA141037_1',
#  'SAG_T1KM_Glioma_GBM_TCGA020064_1',
#  'COR_T1KM_Glioma_GBM_TCGA061084_3']

# %% [markdown]
# Create dictionary to be saved as json file
#
# Each image has it's own id number (ranging from 0 to n-images)

# %%
json_dict = {}

for i, string in enumerate(string_file_list):
    if string != '':
        components = string.split('_')
        """
        Total 6 components:
        0) Perspective - AX/SAG/COR
        1) MRI Sequence - T1/T2/T1KM/PD etc.
        2) Glioma - can ignore for now
        3) GBM - can ignore for now
        4) Patient ID - TCGAXXXXXX
        5) Image number - 1/2/3 etc.
        """
        # temp dict to store important information for each image
        temp_dict = {
            'patient-id': components[4],
            'perspective': components[0],
            'sequence': components[1],
            'perspective-sequence': components[0] + '-' + components[1],
            'labels': [components[0], components[1]],
            'image-number': components[5],
            'image-name': string + '.jpg'
        }
        json_dict[i] = temp_dict

# %%
print('There are {} images in the json.'.format(len(json_dict)))
# Out:
# There are 409 images in the json.

# %%
#json_dict

# %% [markdown]
# Save .json file

# %%
with open('mri-images.json', 'w') as fp:
    json.dump(json_dict, fp)
