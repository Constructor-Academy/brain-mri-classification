# %% [markdown]
# # CNN with Transfer Learning
# **Using ResNet-50** and Keras Functional API
#
# ---
#
# ## Import Libraries

# %%
import numpy as np
import pandas as pd
import os
import glob
import PIL
import cv2
import matplotlib.pyplot as plt

from datetime import datetime

#!pip install ipdb
#import ipdb

# #------------tensorboard libraries--------------
# !pip install -U tensorboard_plugin_profile

import tensorflow_datasets as tfds
tfds.disable_progress_bar()

# #------------tensorflow libraries-----------------
import tensorflow as tf
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.optimizers import Adam

# print('tensorflow version: ', tf.__version__)
# print('GPUs available: {}'.format(tf.config.list_physical_devices('GPU')))
# Out:
# Collecting tensorboard_plugin_profile
#   Downloading https://files.pythonhosted.org/packages/20/03/f4360c57a78c78fad63823b0abe65e589e98ec40ce9e41c549d46efcba75/tensorboard_plugin_profile-2.3.0-py3-none-any.whl (1.1MB)
#      |████████████████████████████████| 1.1MB 4.8MB/s
# Requirement already satisfied, skipping upgrade: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard_plugin_profile) (1.15.0)
# Requirement already satisfied, skipping upgrade: protobuf>=3.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard_plugin_profile) (3.12.2)
# Collecting gviz-api>=1.9.0
#   Downloading https://files.pythonhosted.org/packages/8c/8f/c6f16235a16b3dc4efdcf34dbc93b3b6f678b88176dbd6a36c75d678888f/gviz_api-1.9.0-py2.py3-none-any.whl
# Requirement already satisfied, skipping upgrade: setuptools>=41.0.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard_plugin_profile) (49.1.0)
# Requirement already satisfied, skipping upgrade: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard_plugin_profile) (1.0.1)
# Installing collected packages: gviz-api, tensorboard-plugin-profile
# Successfully installed gviz-api-1.9.0 tensorboard-plugin-profile-2.3.0

# %% [markdown]
# ## Mount Drive and Import Data

# %%
from google.colab import drive
#drive.flush_and_unmount()
drive.mount('/gdrive', force_remount=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /gdrive

# %%
project_dir = '/gdrive/My Drive/Colab Notebooks/MRI'

images_dir = project_dir + '/data/images'
# %cd {project_dir} 
# %pwd
# Out:
# /gdrive/My Drive/Colab Notebooks/MRI
# '/gdrive/My Drive/Colab Notebooks/MRI'

# %%
import cnn_helper as hp
json_dir = project_dir + '/data'
df = hp.load_json_as_df(json_dir, 'mri-images')
df.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# loaded mri-images.json with shape (409, 7)
#    patient-id perspective  ... image-number                          image-name
# 0  TCGA120616          AX  ...            1  AX_ADC_Glioma_GBM_TCGA120616_1.jpg
# 1  TCGA120616          AX  ...            2  AX_ADC_Glioma_GBM_TCGA120616_2.jpg
# 2  TCGA764934          AX  ...            1  AX_ADC_Glioma_GBM_TCGA764934_1.jpg
# 3  TCGA764934          AX  ...            2  AX_ADC_Glioma_GBM_TCGA764934_2.jpg
# 4  TCGA766661          AX  ...            1  AX_ADC_Glioma_GBM_TCGA766661_1.jpg
#
# [5 rows x 7 columns]

# %% [markdown]
# ## Data Generation

# %%
# select column on which to train the model
# can be perspective, sequence or perspective-sequence

x_col = 'image-name' # column in the df with full image names
y_col = 'sequence'

print("'{}' column contains {} unique classes".format(y_col,df[y_col].unique().shape[0]))
# Out:
# 'sequence' column contains 9 unique classes

# %%
hp.plot_class_balances(df, y_col)

# %% [markdown]
# Try on T1KM, T1, T2 and DWI only first. Only use if `y_col` = `sequence`!

# %%
wanted = ['T1KM', 'T1', 'T2', 'DWI']
df = df.loc[df['sequence'].isin(wanted)]
#drop = ['Misc', 'MRA', 'PD', 'ADC', 'PWI']
#drop2 = ['COR-T2']
#df = df.loc[~df['sequence'].isin(drop)]
#df = df.loc[~df['perspective-sequence'].isin(drop2)]

# %% [markdown]
# The classes are highly imbalanced, need to adjust using sampling and/or class weights
#
# Get training, validation and test sets from data

# %%
from sklearn.model_selection import train_test_split
df_train_full, df_test = train_test_split(df, test_size=0.1, random_state=42)
df_train, df_val = train_test_split(df_train_full, test_size=0.2, random_state=42)

# %% [markdown]
# ## Data Sampling
#
# This function performs upsampling or downsampling to balance the dataset.
#
# - df: dataframe to sample
# - col: (string) name of column with the classes to use for samping and balancing
# - n_sample_per_class: (int) max number of samples to take for each class
# - replace: (bool) create duplicates to balance the classes (upsample)

# %%
max_train_pics = 160
max_val_pics = int(.2 * max_train_pics)

df_train = hp.sample_df(df_train, 
                      y_col,
                      n_sample_per_class=max_train_pics,
                      replace = True
                      )

df_test = hp.sample_df(df_test, 
                      y_col,
                      n_sample_per_class=max_val_pics,
                      replace = True
                      )

df_val = hp.sample_df(df_val, 
                      y_col,
                      n_sample_per_class=max_val_pics,
                      replace = True
                      )

# %%
hp.plot_class_balances(df_train, y_col)

# %% [markdown]
# ## Data Augmentation
#
# Generating more data from existing images by applying transformations (e.g. rotation, shifting, zoom, etc.)
#
# ImageDataGenerator documentation: https://www.tensorflow.org/api_docs/python/tf/keras/preprocessing/image/ImageDataGenerator

# %%
IMG_SIZE = 224
num_classes = df[y_col].nunique()
# need a batch size where mod with num test imgs is zero
# only works when sampling with replacement
#batch_size = np.int(max_val_pics * num_classes / 2)
batch_size = 50

#need to pass the class names to the .flow_from_dataframe method
train_classes = df_train[y_col].unique()
train_classes = np.sort(train_classes).tolist()

datagen_train=tf.keras.preprocessing.image.ImageDataGenerator(
                      rescale=1./255,
                       rotation_range=15,
                       width_shift_range=0.1,
                       height_shift_range=0.1,
                       #shear_range=0.005,
                       zoom_range=[0.9, 1.2],
                       horizontal_flip=True,
                       vertical_flip=False,
                       brightness_range=(.8,1.2),
                       fill_mode='nearest',
                      )

train_generator=datagen_train.flow_from_dataframe(
    dataframe=df_train,
    directory=images_dir,
    shuffle=True,
    x_col=x_col,
    y_col=y_col,
  # save_to_dir=savepath + '/aug_images', 
    classes=train_classes,
    class_mode='sparse',
    target_size=(IMG_SIZE, IMG_SIZE), 
    batch_size=batch_size)
# Out:
# Found 640 validated image filenames belonging to 4 classes.

# %% [markdown]
# The data-generator will return a tensor with the images converted to tensors and the true classes for each batch of images
#
# The batch-size that can be loaded is limited by the amount of RAM on the GPU. Higher batch sizes will train faster but setting the batch size too high will cause a memory error. (If you get an error during training try using smaller batches).
#
# We also need a data-generator for the val-set and the test-set, but this should not do any transformations to the images because we want to know the exact classification accuracy on those specific images. So we just rescale the pixel-values so they are between 0.0 and 1.0 because this is expected by the
# model.

# %%
datagen_val=tf.keras.preprocessing.image.ImageDataGenerator(
                      rescale=1./255
                      )

val_generator=datagen_val.flow_from_dataframe(
    dataframe=df_val,
    directory=images_dir, 
    x_col=x_col,
    y_col=y_col,
    class_mode='sparse',
    classes=train_classes,
    shuffle=False,
    target_size=(IMG_SIZE, IMG_SIZE), 
    batch_size=batch_size)

test_generator = datagen_val.flow_from_dataframe(
    dataframe=df_test,
    directory=images_dir, 
    x_col=x_col,
    y_col=y_col,
    class_mode='sparse',
    classes=train_classes,
    shuffle=False,
    target_size=(IMG_SIZE, IMG_SIZE), 
    batch_size=batch_size)
# Out:
# Found 128 validated image filenames belonging to 4 classes.
# Found 128 validated image filenames belonging to 4 classes.

# %%
# Plot 5 augmentations of 1st image in train generator
augmented_images = [train_generator[0][0][0] for i in range(5)]
hp.plot_images(augmented_images)

# %%
# Plot 5 images from the train generator
sample_training_images, _ = next(train_generator)
hp.plot_images(sample_training_images[:5])

# %% [markdown]
# ## Defining Step Size

# %%
# Since the step_size can not be in decimal places it has been rounded
steps_train = round(train_generator.n / batch_size)
steps_val = round(val_generator.n / batch_size)
steps_test = round(test_generator.n / batch_size)

# %%
# Get the class-numbers for all the images in the training- and test-sets
cls_train = train_generator.classes
cls_test = test_generator.classes
len(cls_train)
# Out:
# 640

# %% [markdown]
# ## Class Weights
#
# To adjust for data imbalance between classes.
#
# More information: https://towardsdatascience.com/practical-tips-for-class-imbalance-in-binary-classification-6ee29bcdb8a7

# %%
from sklearn.utils.class_weight import compute_class_weight
class_weight = compute_class_weight(class_weight='balanced',
                                    classes=np.unique(cls_train),
                                    y=cls_train)
class_weight
# Out:
# array([1., 1., 1., 1.])

# %%
# class_weight has to be a dictionary format
class_weight_dict = { i : class_weight[i] for i in range(0, len(class_weight) ) }
class_weight_dict
# Out:
# {0: 1.0, 1: 1.0, 2: 1.0, 3: 1.0}

# %% [markdown]
# ## Create Model Instance
#
# To use ResNet-50 model as a base for transfer learning, we need to create a new model with the final layers suited to our number of classes.
#
# There are multiple ways to do this,   but we will reload the model and specifiy that we only want to load the convolutional layers. This is done
# by setting the keyword parameter `include_top=False`

# %%
input_shape = (224, 224, 3)
img_inputs = tf.keras.Input(shape=input_shape)

# %%
# load a new instance of the model
resnet = tf.keras.applications.resnet50.ResNet50(input_shape=input_shape,
                                              include_top=False,
                                              weights='imagenet',
                                              input_tensor=img_inputs
                                                    )

last_layer = resnet.get_layer('conv5_block3_out')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94773248/94765736 [==============================] - 1s 0us/step

# %% [markdown]
# Using the Keras API it is very simple to create a new model. First we take the part of the base model from its input-layer to the output of the transfer-layer. We may call this the convolutional model, because it consists of all the convolutional layers from the base model.

# %%
# load layers
ga_pooling = tf.keras.layers.GlobalAveragePooling2D()
dropout = tf.keras.layers.Dropout(0.2, seed=42)
softmax = tf.keras.layers.Dense(num_classes, activation='softmax')

# propagate resnet output
pool_img = ga_pooling(last_layer.output)
do_out = dropout(pool_img, training=True) # training=True for MC Dropout
output = softmax(do_out)

# %%
model = tf.keras.Model(inputs=img_inputs, outputs=output, name='func_resnet')
model.summary()
# Out:
# Model: "func_resnet"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 230, 230, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 112, 112, 64) 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 112, 112, 64) 256         conv1_conv[0][0]
# __________________________________________________________________________________________________
# conv1_relu (Activation)         (None, 112, 112, 64) 0           conv1_bn[0][0]
# __________________________________________________________________________________________________
# pool1_pad (ZeroPadding2D)       (None, 114, 114, 64) 0           conv1_relu[0][0]
# __________________________________________________________________________________________________
# pool1_pool (MaxPooling2D)       (None, 56, 56, 64)   0           pool1_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_conv (Conv2D)    (None, 56, 56, 64)   4160        pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_relu (Activation (None, 56, 56, 64)   0           conv2_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_conv (Conv2D)    (None, 56, 56, 64)   36928       conv2_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_relu (Activation (None, 56, 56, 64)   0           conv2_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_conv (Conv2D)    (None, 56, 56, 256)  16640       pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_conv (Conv2D)    (None, 56, 56, 256)  16640       conv2_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_bn (BatchNormali (None, 56, 56, 256)  1024        conv2_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_bn (BatchNormali (None, 56, 56, 256)  1024        conv2_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_add (Add)          (None, 56, 56, 256)  0           conv2_block1_0_bn[0][0]
#                                                                  conv2_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_out (Activation)   (None, 56, 56, 256)  0           conv2_block1_add[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_conv (Conv2D)    (None, 56, 56, 64)   16448       conv2_block1_out[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_relu (Activation (None, 56, 56, 64)   0           conv2_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_conv (Conv2D)    (None, 56, 56, 64)   36928       conv2_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_relu (Activation (None, 56, 56, 64)   0           conv2_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_conv (Conv2D)    (None, 56, 56, 256)  16640       conv2_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_bn (BatchNormali (None, 56, 56, 256)  1024        conv2_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_add (Add)          (None, 56, 56, 256)  0           conv2_block1_out[0][0]
#                                                                  conv2_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_out (Activation)   (None, 56, 56, 256)  0           conv2_block2_add[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_conv (Conv2D)    (None, 56, 56, 64)   16448       conv2_block2_out[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_relu (Activation (None, 56, 56, 64)   0           conv2_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_conv (Conv2D)    (None, 56, 56, 64)   36928       conv2_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_relu (Activation (None, 56, 56, 64)   0           conv2_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_conv (Conv2D)    (None, 56, 56, 256)  16640       conv2_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_bn (BatchNormali (None, 56, 56, 256)  1024        conv2_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_add (Add)          (None, 56, 56, 256)  0           conv2_block2_out[0][0]
#                                                                  conv2_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_out (Activation)   (None, 56, 56, 256)  0           conv2_block3_add[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_conv (Conv2D)    (None, 28, 28, 128)  32896       conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_relu (Activation (None, 28, 28, 128)  0           conv3_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_conv (Conv2D)    (None, 28, 28, 128)  147584      conv3_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_relu (Activation (None, 28, 28, 128)  0           conv3_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_conv (Conv2D)    (None, 28, 28, 512)  131584      conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_add (Add)          (None, 28, 28, 512)  0           conv3_block1_0_bn[0][0]
#                                                                  conv3_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_out (Activation)   (None, 28, 28, 512)  0           conv3_block1_add[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_conv (Conv2D)    (None, 28, 28, 128)  65664       conv3_block1_out[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_relu (Activation (None, 28, 28, 128)  0           conv3_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_conv (Conv2D)    (None, 28, 28, 128)  147584      conv3_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_relu (Activation (None, 28, 28, 128)  0           conv3_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_add (Add)          (None, 28, 28, 512)  0           conv3_block1_out[0][0]
#                                                                  conv3_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_out (Activation)   (None, 28, 28, 512)  0           conv3_block2_add[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_conv (Conv2D)    (None, 28, 28, 128)  65664       conv3_block2_out[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_relu (Activation (None, 28, 28, 128)  0           conv3_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_conv (Conv2D)    (None, 28, 28, 128)  147584      conv3_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_relu (Activation (None, 28, 28, 128)  0           conv3_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_add (Add)          (None, 28, 28, 512)  0           conv3_block2_out[0][0]
#                                                                  conv3_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_out (Activation)   (None, 28, 28, 512)  0           conv3_block3_add[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_conv (Conv2D)    (None, 28, 28, 128)  65664       conv3_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_relu (Activation (None, 28, 28, 128)  0           conv3_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_conv (Conv2D)    (None, 28, 28, 128)  147584      conv3_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_relu (Activation (None, 28, 28, 128)  0           conv3_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_add (Add)          (None, 28, 28, 512)  0           conv3_block3_out[0][0]
#                                                                  conv3_block4_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_out (Activation)   (None, 28, 28, 512)  0           conv3_block4_add[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_conv (Conv2D)    (None, 14, 14, 256)  131328      conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_relu (Activation (None, 14, 14, 256)  0           conv4_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_relu (Activation (None, 14, 14, 256)  0           conv4_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_conv (Conv2D)    (None, 14, 14, 1024) 525312      conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_add (Add)          (None, 14, 14, 1024) 0           conv4_block1_0_bn[0][0]
#                                                                  conv4_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_out (Activation)   (None, 14, 14, 1024) 0           conv4_block1_add[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block1_out[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_relu (Activation (None, 14, 14, 256)  0           conv4_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_relu (Activation (None, 14, 14, 256)  0           conv4_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_add (Add)          (None, 14, 14, 1024) 0           conv4_block1_out[0][0]
#                                                                  conv4_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_out (Activation)   (None, 14, 14, 1024) 0           conv4_block2_add[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block2_out[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_relu (Activation (None, 14, 14, 256)  0           conv4_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_relu (Activation (None, 14, 14, 256)  0           conv4_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_add (Add)          (None, 14, 14, 1024) 0           conv4_block2_out[0][0]
#                                                                  conv4_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_out (Activation)   (None, 14, 14, 1024) 0           conv4_block3_add[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block3_out[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_relu (Activation (None, 14, 14, 256)  0           conv4_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_relu (Activation (None, 14, 14, 256)  0           conv4_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_add (Add)          (None, 14, 14, 1024) 0           conv4_block3_out[0][0]
#                                                                  conv4_block4_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_out (Activation)   (None, 14, 14, 1024) 0           conv4_block4_add[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_relu (Activation (None, 14, 14, 256)  0           conv4_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_relu (Activation (None, 14, 14, 256)  0           conv4_block5_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block5_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block5_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_add (Add)          (None, 14, 14, 1024) 0           conv4_block4_out[0][0]
#                                                                  conv4_block5_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_out (Activation)   (None, 14, 14, 1024) 0           conv4_block5_add[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block5_out[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_relu (Activation (None, 14, 14, 256)  0           conv4_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_relu (Activation (None, 14, 14, 256)  0           conv4_block6_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block6_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block6_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_add (Add)          (None, 14, 14, 1024) 0           conv4_block5_out[0][0]
#                                                                  conv4_block6_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_out (Activation)   (None, 14, 14, 1024) 0           conv4_block6_add[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_conv (Conv2D)    (None, 7, 7, 512)    524800      conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_relu (Activation (None, 7, 7, 512)    0           conv5_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_conv (Conv2D)    (None, 7, 7, 512)    2359808     conv5_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_relu (Activation (None, 7, 7, 512)    0           conv5_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_conv (Conv2D)    (None, 7, 7, 2048)   2099200     conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_conv (Conv2D)    (None, 7, 7, 2048)   1050624     conv5_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_add (Add)          (None, 7, 7, 2048)   0           conv5_block1_0_bn[0][0]
#                                                                  conv5_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_out (Activation)   (None, 7, 7, 2048)   0           conv5_block1_add[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_conv (Conv2D)    (None, 7, 7, 512)    1049088     conv5_block1_out[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_relu (Activation (None, 7, 7, 512)    0           conv5_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_conv (Conv2D)    (None, 7, 7, 512)    2359808     conv5_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_relu (Activation (None, 7, 7, 512)    0           conv5_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_conv (Conv2D)    (None, 7, 7, 2048)   1050624     conv5_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_add (Add)          (None, 7, 7, 2048)   0           conv5_block1_out[0][0]
#                                                                  conv5_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_out (Activation)   (None, 7, 7, 2048)   0           conv5_block2_add[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_conv (Conv2D)    (None, 7, 7, 512)    1049088     conv5_block2_out[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_relu (Activation (None, 7, 7, 512)    0           conv5_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_conv (Conv2D)    (None, 7, 7, 512)    2359808     conv5_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_relu (Activation (None, 7, 7, 512)    0           conv5_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_conv (Conv2D)    (None, 7, 7, 2048)   1050624     conv5_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_add (Add)          (None, 7, 7, 2048)   0           conv5_block2_out[0][0]
#                                                                  conv5_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_out (Activation)   (None, 7, 7, 2048)   0           conv5_block3_add[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 2048)         0           conv5_block3_out[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 2048)         0           global_average_pooling2d[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 4)            8196        dropout[0][0]
# ==================================================================================================
# Total params: 23,595,908
# Trainable params: 23,542,788
# Non-trainable params: 53,120
# __________________________________________________________________________________________________

# %%
optimizer = Adam(lr=1e-4)
optimizer.lr.numpy()
# Out:
# 1e-04

# %% [markdown]
# We have multiple categorical classes in a single column so we need to use a sparse categorical loss function

# %%
loss = 'sparse_categorical_crossentropy'

# %%
lst_metrics = ['sparse_categorical_accuracy']

# %%
model.compile(optimizer=optimizer, loss=loss, metrics=lst_metrics)

# %% [markdown]
# ## Transfer Learning
#
# In Transfer Learning the original pre-trained model is locked or frozen during training of the new classifier. This ensures that the weights of the original model will not change. One advantage of this, is that the training of the new classifier will not propagate large gradients back through the model that may either distort its weights or cause overfitting to the new dataset.

# %%
for layer in model.layers[0:-3]:
  layer.trainable = False

# %%
model.summary()
# Out:
# Model: "func_resnet"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 230, 230, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 112, 112, 64) 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 112, 112, 64) 256         conv1_conv[0][0]
# __________________________________________________________________________________________________
# conv1_relu (Activation)         (None, 112, 112, 64) 0           conv1_bn[0][0]
# __________________________________________________________________________________________________
# pool1_pad (ZeroPadding2D)       (None, 114, 114, 64) 0           conv1_relu[0][0]
# __________________________________________________________________________________________________
# pool1_pool (MaxPooling2D)       (None, 56, 56, 64)   0           pool1_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_conv (Conv2D)    (None, 56, 56, 64)   4160        pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_relu (Activation (None, 56, 56, 64)   0           conv2_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_conv (Conv2D)    (None, 56, 56, 64)   36928       conv2_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_relu (Activation (None, 56, 56, 64)   0           conv2_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_conv (Conv2D)    (None, 56, 56, 256)  16640       pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_conv (Conv2D)    (None, 56, 56, 256)  16640       conv2_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_bn (BatchNormali (None, 56, 56, 256)  1024        conv2_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_bn (BatchNormali (None, 56, 56, 256)  1024        conv2_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_add (Add)          (None, 56, 56, 256)  0           conv2_block1_0_bn[0][0]
#                                                                  conv2_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_out (Activation)   (None, 56, 56, 256)  0           conv2_block1_add[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_conv (Conv2D)    (None, 56, 56, 64)   16448       conv2_block1_out[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_relu (Activation (None, 56, 56, 64)   0           conv2_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_conv (Conv2D)    (None, 56, 56, 64)   36928       conv2_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_relu (Activation (None, 56, 56, 64)   0           conv2_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_conv (Conv2D)    (None, 56, 56, 256)  16640       conv2_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_bn (BatchNormali (None, 56, 56, 256)  1024        conv2_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_add (Add)          (None, 56, 56, 256)  0           conv2_block1_out[0][0]
#                                                                  conv2_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_out (Activation)   (None, 56, 56, 256)  0           conv2_block2_add[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_conv (Conv2D)    (None, 56, 56, 64)   16448       conv2_block2_out[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_relu (Activation (None, 56, 56, 64)   0           conv2_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_conv (Conv2D)    (None, 56, 56, 64)   36928       conv2_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_relu (Activation (None, 56, 56, 64)   0           conv2_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_conv (Conv2D)    (None, 56, 56, 256)  16640       conv2_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_bn (BatchNormali (None, 56, 56, 256)  1024        conv2_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_add (Add)          (None, 56, 56, 256)  0           conv2_block2_out[0][0]
#                                                                  conv2_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_out (Activation)   (None, 56, 56, 256)  0           conv2_block3_add[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_conv (Conv2D)    (None, 28, 28, 128)  32896       conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_relu (Activation (None, 28, 28, 128)  0           conv3_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_conv (Conv2D)    (None, 28, 28, 128)  147584      conv3_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_relu (Activation (None, 28, 28, 128)  0           conv3_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_conv (Conv2D)    (None, 28, 28, 512)  131584      conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_add (Add)          (None, 28, 28, 512)  0           conv3_block1_0_bn[0][0]
#                                                                  conv3_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_out (Activation)   (None, 28, 28, 512)  0           conv3_block1_add[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_conv (Conv2D)    (None, 28, 28, 128)  65664       conv3_block1_out[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_relu (Activation (None, 28, 28, 128)  0           conv3_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_conv (Conv2D)    (None, 28, 28, 128)  147584      conv3_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_relu (Activation (None, 28, 28, 128)  0           conv3_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_add (Add)          (None, 28, 28, 512)  0           conv3_block1_out[0][0]
#                                                                  conv3_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_out (Activation)   (None, 28, 28, 512)  0           conv3_block2_add[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_conv (Conv2D)    (None, 28, 28, 128)  65664       conv3_block2_out[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_relu (Activation (None, 28, 28, 128)  0           conv3_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_conv (Conv2D)    (None, 28, 28, 128)  147584      conv3_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_relu (Activation (None, 28, 28, 128)  0           conv3_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_add (Add)          (None, 28, 28, 512)  0           conv3_block2_out[0][0]
#                                                                  conv3_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_out (Activation)   (None, 28, 28, 512)  0           conv3_block3_add[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_conv (Conv2D)    (None, 28, 28, 128)  65664       conv3_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_relu (Activation (None, 28, 28, 128)  0           conv3_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_conv (Conv2D)    (None, 28, 28, 128)  147584      conv3_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_relu (Activation (None, 28, 28, 128)  0           conv3_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_add (Add)          (None, 28, 28, 512)  0           conv3_block3_out[0][0]
#                                                                  conv3_block4_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_out (Activation)   (None, 28, 28, 512)  0           conv3_block4_add[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_conv (Conv2D)    (None, 14, 14, 256)  131328      conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_relu (Activation (None, 14, 14, 256)  0           conv4_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_relu (Activation (None, 14, 14, 256)  0           conv4_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_conv (Conv2D)    (None, 14, 14, 1024) 525312      conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_add (Add)          (None, 14, 14, 1024) 0           conv4_block1_0_bn[0][0]
#                                                                  conv4_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_out (Activation)   (None, 14, 14, 1024) 0           conv4_block1_add[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block1_out[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_relu (Activation (None, 14, 14, 256)  0           conv4_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_relu (Activation (None, 14, 14, 256)  0           conv4_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_add (Add)          (None, 14, 14, 1024) 0           conv4_block1_out[0][0]
#                                                                  conv4_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_out (Activation)   (None, 14, 14, 1024) 0           conv4_block2_add[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block2_out[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_relu (Activation (None, 14, 14, 256)  0           conv4_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_relu (Activation (None, 14, 14, 256)  0           conv4_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_add (Add)          (None, 14, 14, 1024) 0           conv4_block2_out[0][0]
#                                                                  conv4_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_out (Activation)   (None, 14, 14, 1024) 0           conv4_block3_add[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block3_out[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_relu (Activation (None, 14, 14, 256)  0           conv4_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_relu (Activation (None, 14, 14, 256)  0           conv4_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_add (Add)          (None, 14, 14, 1024) 0           conv4_block3_out[0][0]
#                                                                  conv4_block4_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_out (Activation)   (None, 14, 14, 1024) 0           conv4_block4_add[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_relu (Activation (None, 14, 14, 256)  0           conv4_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_relu (Activation (None, 14, 14, 256)  0           conv4_block5_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block5_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block5_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_add (Add)          (None, 14, 14, 1024) 0           conv4_block4_out[0][0]
#                                                                  conv4_block5_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_out (Activation)   (None, 14, 14, 1024) 0           conv4_block5_add[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block5_out[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_relu (Activation (None, 14, 14, 256)  0           conv4_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_relu (Activation (None, 14, 14, 256)  0           conv4_block6_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block6_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block6_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_add (Add)          (None, 14, 14, 1024) 0           conv4_block5_out[0][0]
#                                                                  conv4_block6_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_out (Activation)   (None, 14, 14, 1024) 0           conv4_block6_add[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_conv (Conv2D)    (None, 7, 7, 512)    524800      conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_relu (Activation (None, 7, 7, 512)    0           conv5_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_conv (Conv2D)    (None, 7, 7, 512)    2359808     conv5_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_relu (Activation (None, 7, 7, 512)    0           conv5_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_conv (Conv2D)    (None, 7, 7, 2048)   2099200     conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_conv (Conv2D)    (None, 7, 7, 2048)   1050624     conv5_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_add (Add)          (None, 7, 7, 2048)   0           conv5_block1_0_bn[0][0]
#                                                                  conv5_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_out (Activation)   (None, 7, 7, 2048)   0           conv5_block1_add[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_conv (Conv2D)    (None, 7, 7, 512)    1049088     conv5_block1_out[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_relu (Activation (None, 7, 7, 512)    0           conv5_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_conv (Conv2D)    (None, 7, 7, 512)    2359808     conv5_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_relu (Activation (None, 7, 7, 512)    0           conv5_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_conv (Conv2D)    (None, 7, 7, 2048)   1050624     conv5_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_add (Add)          (None, 7, 7, 2048)   0           conv5_block1_out[0][0]
#                                                                  conv5_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_out (Activation)   (None, 7, 7, 2048)   0           conv5_block2_add[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_conv (Conv2D)    (None, 7, 7, 512)    1049088     conv5_block2_out[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_relu (Activation (None, 7, 7, 512)    0           conv5_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_conv (Conv2D)    (None, 7, 7, 512)    2359808     conv5_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_relu (Activation (None, 7, 7, 512)    0           conv5_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_conv (Conv2D)    (None, 7, 7, 2048)   1050624     conv5_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_add (Add)          (None, 7, 7, 2048)   0           conv5_block2_out[0][0]
#                                                                  conv5_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_out (Activation)   (None, 7, 7, 2048)   0           conv5_block3_add[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 2048)         0           conv5_block3_out[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 2048)         0           global_average_pooling2d[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 4)            8196        dropout[0][0]
# ==================================================================================================
# Total params: 23,595,908
# Trainable params: 8,196
# Non-trainable params: 23,587,712
# __________________________________________________________________________________________________

# %% [markdown]
# ## Create TensorBoard Callbacks

# %%
logs = "data/logs/" + datetime.now().strftime("%Y%m%d-%H%M%S")
# Uncomment when running for the fist time and change file name accordingly
logs = "data/logs/" +"bayesian_sequence4_augmentation_closed_160replace_epoch100_lr1e-4_dropout.2_transferlearning"

tboard_callback = tf.keras.callbacks.TensorBoard(log_dir = logs,
                                                 histogram_freq = 1,
                                                 profile_batch = '500,520')

# %% [markdown]
# Early stopping gets stuck in the initial stages where the validation accuracy may be constant for 30+ epochs. Could increase `patience` to 30+ but that defeats the purpose of early stopping in my opinion. Not recommended

# %%
"""
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor="val_sparse_categorical_accuracy",
    patience=10,
    verbose=1,
    min_delta=0.01,
    restore_best_weights=True,
    mode='max'
)
"""
# Out:
# '\nearly_stopping = tf.keras.callbacks.EarlyStopping(\n    monitor="val_sparse_categorical_accuracy",\n    patience=10,\n    verbose=1,\n    min_delta=0.01,\n    restore_best_weights=True,\n    mode=\'max\'\n)\n'

# %% [markdown]
# ## Train Model

# %%
epochs = 100

# %%
history = model.fit(train_generator,
                    epochs=epochs,
                    steps_per_epoch=steps_train,
                    class_weight=class_weight_dict,
                    validation_data=val_generator,
                    callbacks = [tboard_callback]
                    )
# Out:
# Epoch 1/100
# 13/13 [==============================] - 81s 6s/step - loss: 0.5814 - sparse_categorical_accuracy: 0.7406 - val_loss: 1.8368 - val_sparse_categorical_accuracy: 0.2500
# Epoch 2/100
# 13/13 [==============================] - 17s 1s/step - loss: 0.0610 - sparse_categorical_accuracy: 0.9828 - val_loss: 1.8913 - val_sparse_categorical_accuracy: 0.2656
# Epoch 3/100
# 13/13 [==============================] - 17s 1s/step - loss: 0.0181 - sparse_categorical_accuracy: 0.9937 - val_loss: 1.7861 - val_sparse_categorical_accuracy: 0.2656
# Epoch 4/100
# 13/13 [==============================] - 17s 1s/step - loss: 0.0113 - sparse_categorical_accuracy: 0.9969 - val_loss: 1.6174 - val_sparse_categorical_accuracy: 0.2734
# Epoch 5/100
# 13/13 [==============================] - 17s 1s/step - loss: 0.0073 - sparse_categorical_accuracy: 0.9984 - val_loss: 1.5486 - val_sparse_categorical_accuracy: 0.2188
# Epoch 6/100
# 13/13 [==============================] - 17s 1s/step - loss: 0.0028 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.5690 - val_sparse_categorical_accuracy: 0.2578
# Epoch 7/100
# 13/13 [==============================] - 17s 1s/step - loss: 0.0042 - sparse_categorical_accuracy: 0.9984 - val_loss: 1.6079 - val_sparse_categorical_accuracy: 0.2500
# Epoch 8/100
# 13/13 [==============================] - 17s 1s/step - loss: 0.0052 - sparse_categorical_accuracy: 0.9984 - val_loss: 1.5761 - val_sparse_categorical_accuracy: 0.2656
# Epoch 9/100
# 13/13 [==============================] - 17s 1s/step - loss: 0.0069 - sparse_categorical_accuracy: 0.9969 - val_loss: 1.5547 - val_sparse_categorical_accuracy: 0.2266
# Epoch 10/100
# 13/13 [==============================] - 17s 1s/step - loss: 0.0070 - sparse_categorical_accuracy: 0.9969 - val_loss: 1.5003 - val_sparse_categorical_accuracy: 0.2578
# Epoch 11/100
# 13/13 [==============================] - 17s 1s/step - loss: 0.0028 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.5661 - val_sparse_categorical_accuracy: 0.2578
# Epoch 12/100
# 13/13 [==============================] - 17s 1s/step - loss: 0.0014 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.4747 - val_sparse_categorical_accuracy: 0.2500
# Epoch 13/100
# 13/13 [==============================] - 17s 1s/step - loss: 5.5525e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.5193 - val_sparse_categorical_accuracy: 0.2266
# Epoch 14/100
# 13/13 [==============================] - 17s 1s/step - loss: 0.0023 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.5348 - val_sparse_categorical_accuracy: 0.2578
# Epoch 15/100
# 13/13 [==============================] - 17s 1s/step - loss: 0.0045 - sparse_categorical_accuracy: 0.9984 - val_loss: 1.5361 - val_sparse_categorical_accuracy: 0.2969
# Epoch 16/100
# 13/13 [==============================] - 17s 1s/step - loss: 0.0019 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.5838 - val_sparse_categorical_accuracy: 0.2812
# Epoch 17/100
# 13/13 [==============================] - 17s 1s/step - loss: 0.0013 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.5598 - val_sparse_categorical_accuracy: 0.2500
# Epoch 18/100
# 13/13 [==============================] - 17s 1s/step - loss: 5.6874e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.5378 - val_sparse_categorical_accuracy: 0.3125
# Epoch 19/100
# 13/13 [==============================] - 17s 1s/step - loss: 0.0212 - sparse_categorical_accuracy: 0.9906 - val_loss: 1.6174 - val_sparse_categorical_accuracy: 0.3125
# Epoch 20/100
# 13/13 [==============================] - 17s 1s/step - loss: 0.0115 - sparse_categorical_accuracy: 0.9953 - val_loss: 2.3938 - val_sparse_categorical_accuracy: 0.2500
# Epoch 21/100
# 13/13 [==============================] - 17s 1s/step - loss: 0.0102 - sparse_categorical_accuracy: 0.9969 - val_loss: 2.1132 - val_sparse_categorical_accuracy: 0.2422
# Epoch 22/100
# 13/13 [==============================] - 17s 1s/step - loss: 0.0124 - sparse_categorical_accuracy: 0.9953 - val_loss: 2.0556 - val_sparse_categorical_accuracy: 0.2500
# Epoch 23/100
# 13/13 [==============================] - 17s 1s/step - loss: 0.0173 - sparse_categorical_accuracy: 0.9937 - val_loss: 1.8797 - val_sparse_categorical_accuracy: 0.2188
# Epoch 24/100
# 13/13 [==============================] - 17s 1s/step - loss: 0.0069 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.7714 - val_sparse_categorical_accuracy: 0.2812
# Epoch 25/100
# 13/13 [==============================] - 17s 1s/step - loss: 0.0193 - sparse_categorical_accuracy: 0.9937 - val_loss: 1.8035 - val_sparse_categorical_accuracy: 0.3438
# Epoch 26/100
# 13/13 [==============================] - 17s 1s/step - loss: 0.0102 - sparse_categorical_accuracy: 0.9969 - val_loss: 1.6692 - val_sparse_categorical_accuracy: 0.2812
# Epoch 27/100
# 13/13 [==============================] - 17s 1s/step - loss: 0.0072 - sparse_categorical_accuracy: 0.9984 - val_loss: 1.6929 - val_sparse_categorical_accuracy: 0.2578
# Epoch 28/100
# 13/13 [==============================] - 17s 1s/step - loss: 0.0103 - sparse_categorical_accuracy: 0.9969 - val_loss: 1.7530 - val_sparse_categorical_accuracy: 0.2266
# Epoch 29/100
# 13/13 [==============================] - 17s 1s/step - loss: 0.0086 - sparse_categorical_accuracy: 0.9984 - val_loss: 1.8979 - val_sparse_categorical_accuracy: 0.2500
# Epoch 30/100
# 13/13 [==============================] - 17s 1s/step - loss: 0.0026 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.8907 - val_sparse_categorical_accuracy: 0.2500
# Epoch 31/100
# 13/13 [==============================] - 17s 1s/step - loss: 0.0013 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.8273 - val_sparse_categorical_accuracy: 0.1953
# Epoch 32/100
# 13/13 [==============================] - 17s 1s/step - loss: 0.0013 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.8127 - val_sparse_categorical_accuracy: 0.2266
# Epoch 33/100
# 13/13 [==============================] - 17s 1s/step - loss: 0.0051 - sparse_categorical_accuracy: 0.9984 - val_loss: 1.9452 - val_sparse_categorical_accuracy: 0.2344
# Epoch 34/100
# 13/13 [==============================] - 17s 1s/step - loss: 0.0017 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.9083 - val_sparse_categorical_accuracy: 0.2188
# Epoch 35/100
# 13/13 [==============================] - 17s 1s/step - loss: 0.0029 - sparse_categorical_accuracy: 0.9984 - val_loss: 1.8378 - val_sparse_categorical_accuracy: 0.1641
# Epoch 36/100
# 13/13 [==============================] - 17s 1s/step - loss: 0.0111 - sparse_categorical_accuracy: 0.9984 - val_loss: 1.9715 - val_sparse_categorical_accuracy: 0.2031
# Epoch 37/100
# 13/13 [==============================] - 17s 1s/step - loss: 0.0014 - sparse_categorical_accuracy: 1.0000 - val_loss: 2.1635 - val_sparse_categorical_accuracy: 0.1953
# Epoch 38/100
# 13/13 [==============================] - 17s 1s/step - loss: 0.0032 - sparse_categorical_accuracy: 1.0000 - val_loss: 2.1425 - val_sparse_categorical_accuracy: 0.2500
# Epoch 39/100
# 13/13 [==============================] - 17s 1s/step - loss: 0.0017 - sparse_categorical_accuracy: 1.0000 - val_loss: 2.0627 - val_sparse_categorical_accuracy: 0.2500
# Epoch 40/100
# 13/13 [==============================] - 19s 1s/step - loss: 0.0036 - sparse_categorical_accuracy: 0.9984 - val_loss: 2.0295 - val_sparse_categorical_accuracy: 0.2500
# Epoch 41/100
# 13/13 [==============================] - 17s 1s/step - loss: 9.1946e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.9175 - val_sparse_categorical_accuracy: 0.3125
# Epoch 42/100
# 13/13 [==============================] - 17s 1s/step - loss: 0.0019 - sparse_categorical_accuracy: 0.9984 - val_loss: 1.8814 - val_sparse_categorical_accuracy: 0.2969
# Epoch 43/100
# 13/13 [==============================] - 17s 1s/step - loss: 6.0360e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.6646 - val_sparse_categorical_accuracy: 0.3359
# Epoch 44/100
# 13/13 [==============================] - 17s 1s/step - loss: 0.0014 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.6121 - val_sparse_categorical_accuracy: 0.3750
# Epoch 45/100
# 13/13 [==============================] - 17s 1s/step - loss: 4.9510e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.5903 - val_sparse_categorical_accuracy: 0.3359
# Epoch 46/100
# 13/13 [==============================] - 17s 1s/step - loss: 1.3896e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.4782 - val_sparse_categorical_accuracy: 0.3828
# Epoch 47/100
# 13/13 [==============================] - 17s 1s/step - loss: 1.7805e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.3750 - val_sparse_categorical_accuracy: 0.4453
# Epoch 48/100
# 13/13 [==============================] - 17s 1s/step - loss: 3.0867e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.2622 - val_sparse_categorical_accuracy: 0.4609
# Epoch 49/100
# 13/13 [==============================] - 17s 1s/step - loss: 2.8383e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.2236 - val_sparse_categorical_accuracy: 0.4609
# Epoch 50/100
# 13/13 [==============================] - 17s 1s/step - loss: 1.1519e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.1585 - val_sparse_categorical_accuracy: 0.5312
# Epoch 51/100
# 13/13 [==============================] - 17s 1s/step - loss: 1.0701e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.0890 - val_sparse_categorical_accuracy: 0.5625
# Epoch 52/100
# 13/13 [==============================] - 17s 1s/step - loss: 8.1947e-05 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.0758 - val_sparse_categorical_accuracy: 0.6016
# Epoch 53/100
# 13/13 [==============================] - 17s 1s/step - loss: 6.0469e-05 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.9569 - val_sparse_categorical_accuracy: 0.6328
# Epoch 54/100
# 13/13 [==============================] - 17s 1s/step - loss: 4.5442e-05 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.9415 - val_sparse_categorical_accuracy: 0.6562
# Epoch 55/100
# 13/13 [==============================] - 17s 1s/step - loss: 6.1570e-05 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.9092 - val_sparse_categorical_accuracy: 0.6797
# Epoch 56/100
# 13/13 [==============================] - 18s 1s/step - loss: 7.1545e-05 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.8629 - val_sparse_categorical_accuracy: 0.7109
# Epoch 57/100
# 13/13 [==============================] - 17s 1s/step - loss: 0.0149 - sparse_categorical_accuracy: 0.9953 - val_loss: 1.2412 - val_sparse_categorical_accuracy: 0.6016
# Epoch 58/100
# 13/13 [==============================] - 17s 1s/step - loss: 0.0205 - sparse_categorical_accuracy: 0.9969 - val_loss: 1.2171 - val_sparse_categorical_accuracy: 0.5859
# Epoch 59/100
# 13/13 [==============================] - 17s 1s/step - loss: 0.0151 - sparse_categorical_accuracy: 0.9953 - val_loss: 1.9314 - val_sparse_categorical_accuracy: 0.5469
# Epoch 60/100
# 13/13 [==============================] - 17s 1s/step - loss: 0.0387 - sparse_categorical_accuracy: 0.9891 - val_loss: 0.5439 - val_sparse_categorical_accuracy: 0.8672
# Epoch 61/100
# 13/13 [==============================] - 17s 1s/step - loss: 0.0242 - sparse_categorical_accuracy: 0.9891 - val_loss: 5.5792 - val_sparse_categorical_accuracy: 0.3984
# Epoch 62/100
# 13/13 [==============================] - 17s 1s/step - loss: 0.0430 - sparse_categorical_accuracy: 0.9875 - val_loss: 4.8595 - val_sparse_categorical_accuracy: 0.3750
# Epoch 63/100
# 13/13 [==============================] - 17s 1s/step - loss: 0.0358 - sparse_categorical_accuracy: 0.9937 - val_loss: 3.0653 - val_sparse_categorical_accuracy: 0.5703
# Epoch 64/100
# 13/13 [==============================] - 17s 1s/step - loss: 0.0057 - sparse_categorical_accuracy: 1.0000 - val_loss: 3.2904 - val_sparse_categorical_accuracy: 0.5547
# Epoch 65/100
# 13/13 [==============================] - 17s 1s/step - loss: 0.0065 - sparse_categorical_accuracy: 0.9969 - val_loss: 3.5369 - val_sparse_categorical_accuracy: 0.6016
# Epoch 66/100
# 13/13 [==============================] - 17s 1s/step - loss: 0.0021 - sparse_categorical_accuracy: 1.0000 - val_loss: 2.4638 - val_sparse_categorical_accuracy: 0.5859
# Epoch 67/100
# 13/13 [==============================] - 17s 1s/step - loss: 4.0203e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.9966 - val_sparse_categorical_accuracy: 0.6172
# Epoch 68/100
# 13/13 [==============================] - 17s 1s/step - loss: 0.0021 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.3952 - val_sparse_categorical_accuracy: 0.6875
# Epoch 69/100
# 13/13 [==============================] - 17s 1s/step - loss: 8.0473e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.2958 - val_sparse_categorical_accuracy: 0.6875
# Epoch 70/100
# 13/13 [==============================] - 17s 1s/step - loss: 2.3607e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.0942 - val_sparse_categorical_accuracy: 0.7188
# Epoch 71/100
# 13/13 [==============================] - 17s 1s/step - loss: 1.7554e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.9580 - val_sparse_categorical_accuracy: 0.7734
# Epoch 72/100
# 13/13 [==============================] - 17s 1s/step - loss: 2.9541e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.8718 - val_sparse_categorical_accuracy: 0.8047
# Epoch 73/100
# 13/13 [==============================] - 17s 1s/step - loss: 6.7404e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.7493 - val_sparse_categorical_accuracy: 0.8750
# Epoch 74/100
# 13/13 [==============================] - 17s 1s/step - loss: 3.7094e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.6996 - val_sparse_categorical_accuracy: 0.8828
# Epoch 75/100
# 13/13 [==============================] - 17s 1s/step - loss: 3.1605e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.6266 - val_sparse_categorical_accuracy: 0.9141
# Epoch 76/100
# 13/13 [==============================] - 17s 1s/step - loss: 6.1005e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.5498 - val_sparse_categorical_accuracy: 0.9219
# Epoch 77/100
# 13/13 [==============================] - 17s 1s/step - loss: 1.7968e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4914 - val_sparse_categorical_accuracy: 0.9219
# Epoch 78/100
# 13/13 [==============================] - 17s 1s/step - loss: 1.3203e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4325 - val_sparse_categorical_accuracy: 0.9219
# Epoch 79/100
# 13/13 [==============================] - 17s 1s/step - loss: 1.9268e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3960 - val_sparse_categorical_accuracy: 0.9219
# Epoch 80/100
# 13/13 [==============================] - 17s 1s/step - loss: 3.5265e-05 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3666 - val_sparse_categorical_accuracy: 0.9219
# Epoch 81/100
# 13/13 [==============================] - 17s 1s/step - loss: 1.2809e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3551 - val_sparse_categorical_accuracy: 0.9219
# Epoch 82/100
# 13/13 [==============================] - 17s 1s/step - loss: 7.4511e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3585 - val_sparse_categorical_accuracy: 0.9219
# Epoch 83/100
# 13/13 [==============================] - 17s 1s/step - loss: 0.0018 - sparse_categorical_accuracy: 0.9984 - val_loss: 0.4347 - val_sparse_categorical_accuracy: 0.9297
# Epoch 84/100
# 13/13 [==============================] - 17s 1s/step - loss: 0.0012 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4833 - val_sparse_categorical_accuracy: 0.9375
# Epoch 85/100
# 13/13 [==============================] - 17s 1s/step - loss: 0.0020 - sparse_categorical_accuracy: 0.9984 - val_loss: 0.4702 - val_sparse_categorical_accuracy: 0.9219
# Epoch 86/100
# 13/13 [==============================] - 17s 1s/step - loss: 0.0046 - sparse_categorical_accuracy: 0.9984 - val_loss: 0.3893 - val_sparse_categorical_accuracy: 0.9219
# Epoch 87/100
# 13/13 [==============================] - 17s 1s/step - loss: 2.3140e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2637 - val_sparse_categorical_accuracy: 0.9375
# Epoch 88/100
# 13/13 [==============================] - 17s 1s/step - loss: 0.0044 - sparse_categorical_accuracy: 0.9969 - val_loss: 0.2144 - val_sparse_categorical_accuracy: 0.9219
# Epoch 89/100
# 13/13 [==============================] - 17s 1s/step - loss: 0.0130 - sparse_categorical_accuracy: 0.9984 - val_loss: 0.1796 - val_sparse_categorical_accuracy: 0.9375
# Epoch 90/100
# 13/13 [==============================] - 17s 1s/step - loss: 9.6289e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2012 - val_sparse_categorical_accuracy: 0.9297
# Epoch 91/100
# 13/13 [==============================] - 17s 1s/step - loss: 3.8137e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.1774 - val_sparse_categorical_accuracy: 0.9453
# Epoch 92/100
# 13/13 [==============================] - 17s 1s/step - loss: 6.4227e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.1331 - val_sparse_categorical_accuracy: 0.9453
# Epoch 93/100
# 13/13 [==============================] - 17s 1s/step - loss: 6.5222e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.1271 - val_sparse_categorical_accuracy: 0.9453
# Epoch 94/100
# 13/13 [==============================] - 17s 1s/step - loss: 4.5787e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.1191 - val_sparse_categorical_accuracy: 0.9375
# Epoch 95/100
# 13/13 [==============================] - 17s 1s/step - loss: 1.1283e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.1059 - val_sparse_categorical_accuracy: 0.9531
# Epoch 96/100
# 13/13 [==============================] - 17s 1s/step - loss: 3.4372e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0866 - val_sparse_categorical_accuracy: 0.9609
# Epoch 97/100
# 13/13 [==============================] - 17s 1s/step - loss: 6.0681e-05 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0864 - val_sparse_categorical_accuracy: 0.9609
# Epoch 98/100
# 13/13 [==============================] - 17s 1s/step - loss: 1.6572e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0816 - val_sparse_categorical_accuracy: 0.9688
# Epoch 99/100
# 13/13 [==============================] - 17s 1s/step - loss: 1.8866e-05 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0840 - val_sparse_categorical_accuracy: 0.9609
# Epoch 100/100
# 13/13 [==============================] - 17s 1s/step - loss: 1.2612e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0763 - val_sparse_categorical_accuracy: 0.9766

# %% [markdown]
# ## Load Saved Model

# %%
model = tf.keras.models.load_model('bayesian_persp-seq_augment_80replace_epoch100_lre-4_closed_dropout.2_94acc.h5')
# Out:
# WARNING:tensorflow:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.

# %% [markdown]
# ## Evaluating Predictions

# %%
# Load the TensorBoard notebook extension.
# %load_ext tensorboard
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %%
# Launch TensorBoard and navigate to the Profile tab to view performance profile
# %tensorboard --logdir=logs

# %%
hp.plot_training_history(history,lst_metrics[0])

# %%
result = model.evaluate(test_generator, steps=steps_test)
print("Test-set classification accuracy: {0:.2%}".format(result[1]))
# Out:
# 3/3 [==============================] - 4s 1s/step - loss: 0.0308 - sparse_categorical_accuracy: 0.9844
# Test-set classification accuracy: 98.44%

# %% [markdown]
# ## Model Validation

# %%
test_history = model.predict(
                        test_generator,
                        steps=steps_test,
                        callbacks=None,
                        max_queue_size=10,
                        workers=-1,
                        use_multiprocessing=False,
                        verbose=1)
# Out:
# 3/3 [==============================] - 1s 303ms/step

# %%
df_res_labels = hp.create_test_report(test_generator, test_history)
# Out:
# ..................................................
# showing test metrics for 128 samples
# ``````````````````````````````````````````````````
#
# precision_macro  0.985294
# accuracy         0.984375
# f1_micro         0.984375
# precision_micro  0.984375
# recall_macro     0.984375
# recall_micro     0.984375
# f1_macro         0.984360
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

# %% [markdown]
# Save current model

# %%
# Save the entire model to a HDF5 file.
# The '.h5' extension indicates that the model shuold be saved to HDF5.
model.save('bayesian_sequence4_augment_160replace_epoch100_lre-4_closed_dropout.2_98acc.h5')

# %% [markdown]
# ## Evaluate Uncertainty with Bayesian Theory
# * Source: https://towardsdatascience.com/when-your-neural-net-doesnt-know-a-bayesian-approach-with-keras-4782c0818624
#
# The idea is to first establish a probability threshold for each class using the validation data. If the probability of a class is too low for a given image, the image will not be labelled as that class. In case this happens for all classes, the image will not be classified.

# %% [markdown]
# Get images from generators

# %%
# test images and labels from generator

test_imgs, test_labels = [], []
for i in range((test_generator.n // batch_size) + 1):
    img, label = test_generator.next()
    test_imgs.append(img)
    test_labels.append(label)
        
test_imgs = np.vstack(test_imgs)
test_labels = np.concatenate(test_labels)

print(test_imgs.shape, test_labels.shape)
# Out:
# (128, 224, 224, 3) (128,)

# %% [markdown]
# Make repeated predictions with Dropout still active to get a distribution

# %%
bayes_pred_dist = []
rep = 100

for i in range(rep):
    bayes_pred_dist.append(model.predict(test_imgs))
    
bayes_pred_dist = np.transpose(np.stack(bayes_pred_dist), (1,0,2))
bayes_pred_dist.shape
# Out:
# (128, 100, 4)

# %% [markdown]
# Visualise probability distribution for specific image

# %%
test_labels[:10]
# Out:
# array([0., 0., 0., 1., 2., 6., 1., 2., 4., 5.], dtype=float32)

# %%
test_id = 77
label_id = np.int(test_labels[test_id])
bin_width = 0.025

for cls in range(num_classes):
    plt.hist(bayes_pred_dist[test_id][:,cls], 
             bins=np.arange(0, 1 + bin_width, bin_width), 
             alpha=0.5, label=train_classes[cls])
    
    #plt.axvline(np.quantile(bayes_pred_dist[test_id][:,cls], 0.5), color='red', linestyle='--', alpha=0.3)
    #plt.axvline(0.5, color='green', linestyle='--', alpha=0.6)
    plt.xlabel('probability'); plt.ylabel('count'); plt.legend()
    plt.title('True label: {}'.format(train_classes[label_id]))
    
    # uncomment to get separate plots per class
    #plt.show()
    
np.set_printoptions(False)

# %%
plt.imshow(test_imgs[test_id])
plt.title('Label: {}'.format(train_classes[label_id]))
plt.show()

# %% [markdown]
# ## View sample of images

# %%
test_results_df = hp.create_res_labels_df(test_generator, test_history)
test_results_df.head()
# Out:
#    y_true  y_pred                                         image_path
# 0       0       0  /gdrive/My Drive/Colab Notebooks/MRI/data/imag...
# 1       0       0  /gdrive/My Drive/Colab Notebooks/MRI/data/imag...
# 2       0       0  /gdrive/My Drive/Colab Notebooks/MRI/data/imag...
# 3       1       1  /gdrive/My Drive/Colab Notebooks/MRI/data/imag...
# 4       2       2  /gdrive/My Drive/Colab Notebooks/MRI/data/imag...

# %%
# class 1 classified as class 2
error_df = test_results_df.loc[(test_results_df['y_true'] != test_results_df['y_pred'])]
# class 1 correctly classified
correct_1_df = test_results_df.loc[(test_results_df['y_true'] == 1) & 
                (test_results_df['y_pred'] == 1)]
# class 2 correctly classified
correct_2_df = test_results_df.loc[(test_results_df['y_true'] == 3) & 
                (test_results_df['y_pred'] == 3)]
error_df
# Out:
#     y_true  y_pred                                         image_path
# 5        6       7  /gdrive/My Drive/Colab Notebooks/MRI/data/imag...
# 9        5       6  /gdrive/My Drive/Colab Notebooks/MRI/data/imag...
# 12       5       7  /gdrive/My Drive/Colab Notebooks/MRI/data/imag...
# 14       5       6  /gdrive/My Drive/Colab Notebooks/MRI/data/imag...
# 20       6       7  /gdrive/My Drive/Colab Notebooks/MRI/data/imag...
# 27       5       6  /gdrive/My Drive/Colab Notebooks/MRI/data/imag...
# 34       6       7  /gdrive/My Drive/Colab Notebooks/MRI/data/imag...
# 36       6       7  /gdrive/My Drive/Colab Notebooks/MRI/data/imag...
# 38       5       7  /gdrive/My Drive/Colab Notebooks/MRI/data/imag...
# 39       6       7  /gdrive/My Drive/Colab Notebooks/MRI/data/imag...
# 46       6       7  /gdrive/My Drive/Colab Notebooks/MRI/data/imag...
# 54       6       7  /gdrive/My Drive/Colab Notebooks/MRI/data/imag...
# 55       6       7  /gdrive/My Drive/Colab Notebooks/MRI/data/imag...
# 56       5       6  /gdrive/My Drive/Colab Notebooks/MRI/data/imag...
# 58       6       7  /gdrive/My Drive/Colab Notebooks/MRI/data/imag...
# 60       5       6  /gdrive/My Drive/Colab Notebooks/MRI/data/imag...
# 64       5       6  /gdrive/My Drive/Colab Notebooks/MRI/data/imag...
# 67       5       7  /gdrive/My Drive/Colab Notebooks/MRI/data/imag...
# 70       5       6  /gdrive/My Drive/Colab Notebooks/MRI/data/imag...
# 71       6       7  /gdrive/My Drive/Colab Notebooks/MRI/data/imag...
# 74       5       6  /gdrive/My Drive/Colab Notebooks/MRI/data/imag...
# 75       5       6  /gdrive/My Drive/Colab Notebooks/MRI/data/imag...
# 77       3       1  /gdrive/My Drive/Colab Notebooks/MRI/data/imag...
# 89       6       7  /gdrive/My Drive/Colab Notebooks/MRI/data/imag...
# 90       5       7  /gdrive/My Drive/Colab Notebooks/MRI/data/imag...
# 91       5       6  /gdrive/My Drive/Colab Notebooks/MRI/data/imag...
# 92       6       7  /gdrive/My Drive/Colab Notebooks/MRI/data/imag...
# 96       5       6  /gdrive/My Drive/Colab Notebooks/MRI/data/imag...
# 99       6       7  /gdrive/My Drive/Colab Notebooks/MRI/data/imag...

# %% [markdown]
# View MRI of perspective 1 wrongly classified as perspective 2

# %%
error_df.loc[0, 'image_path']
# Out:
# '/gdrive/My Drive/Colab Notebooks/MRI/data/images/AX_T2_Glioma_GBM_TCGA120769_1.jpg'

# %%
im_shape = (224, 224)

# %%
img_arr0 = []
for i, path in enumerate(error_df['image_path']):
  img = PIL.Image.open(path)
  img_resized = img.resize(im_shape, PIL.Image.LANCZOS)
  img_arr0.append(np.array(img_resized))

hp.plot_images(img_arr0)

# %% [markdown]
# View correctly classified MRI of class 1

# %%
img_arr1 = []
for path in correct_1_df['image_path'][:5]:
  img = PIL.Image.open(path)
  img_resized = img.resize(im_shape, PIL.Image.LANCZOS)
  img_arr1.append(np.array(img_resized))

hp.plot_images(img_arr1)

# %% [markdown]
# View correctly classified MRI of class 2

# %%
img_arr2 = []
for path in correct_2_df['image_path'][:5]:
  img = PIL.Image.open(path)
  img_resized = img.resize(im_shape, PIL.Image.LANCZOS)
  img_arr2.append(np.array(img_resized))

hp.plot_images(img_arr2)
